# %%
import mediapipe as mp
import pandas as pd
import numpy as np
import cv2
import os

# %%
mp_pose = mp.solutions.pose

# %%
landmarks_points = {
    "nose": 0,
    "left_shoulder": 11, "right_shoulder": 12,
    "left_elbow": 13, "right_elbow": 14,
    "left_wrist": 15, "right_wrist": 16,
    "left_hip": 23, "right_hip": 24,
    "left_knee": 25, "right_knee": 26,
    "left_ankle": 27, "right_ankle": 28,
    "left_heel": 29, "right_heel": 30,
    "left_foot_index": 31, "right_foot_index": 32,
}

col_names = []
for i in range(len(landmarks_points.keys())):
    name = list(landmarks_points.keys())[i]
    col_names.append(name + "_x")
    col_names.append(name + "_y")
    col_names.append(name + "_z")
    col_names.append(name + "_v")

pose_name = col_names.copy()

pose_name.append("pose")

# %%
pose_list = []

main_dir = "./poses_dataset/Images"
pose_dir_list = os.listdir(main_dir)
pose_dir_list.remove('.DS_Store')
print(pose_dir_list)
for i in range(0, len(pose_dir_list)):
    images_dir_list = os.listdir(f"{main_dir}/{pose_dir_list[i]}")
    for l in range(0, len(images_dir_list)):
        pre_list = []
        with mp_pose.Pose(static_image_mode=True, enable_segmentation=True) as pose:
            image = cv2.imread(
                f"{main_dir}/{pose_dir_list[i]}/{images_dir_list[l]}")
            result = pose.process(
                cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

            try:
                predict = True
                for landmarks in result.pose_landmarks.landmark:
                    pre_list.append(landmarks)
            except AttributeError:
                print(
                    f"No points {main_dir}/{pose_dir_list[i]}/{images_dir_list[l]}")
                predict = False

        if predict == True:
            gen1116 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(11, 17)
            ]).flatten().tolist()

            gen2333 = np.array([
                [
                    pre_list[m].x,
                    pre_list[m].y,
                    pre_list[m].z,
                    pre_list[m].visibility
                ] for m in range(23, 33)
            ]).flatten().tolist()

            gen1116.extend(gen2333)

            all_list = [
                pre_list[0].x,
                pre_list[0].y,
                pre_list[0].z,
                pre_list[0].visibility,
            ]

            all_list.extend(gen1116)
            tpl = all_list.copy()
            tpl.append(i)
            pose_list.append(tpl)

data_pose = pd.DataFrame(pose_list, columns=pose_name)
data_pose.to_csv("./csv_files/poses_data_pose.csv", index=False)
# Out:
# ['Phalakasana', 'Vrikshasana', 'Utkata_Konasana', 'Adho_Mukha_Svanasana']
# I0000 00:00:1746425929.113106  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.188200  181285 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.200477  181285 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.225197  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.287586  181295 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.300917  181295 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.327627  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.397543  181303 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.409855  181305 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.434621  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.500128  181312 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.511279  181312 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.534233  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.597818  181320 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.608580  181321 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.632080  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.699580  181331 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.711418  181337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.742036  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.805770  181340 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.817041  181340 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.842212  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425929.904828  181347 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425929.916214  181352 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425929.943033  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425930.008311  181355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425930.020767  181361 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1746425930.044826  174070 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M2
# W0000 00:00:1746425930.108540  181363 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746425930